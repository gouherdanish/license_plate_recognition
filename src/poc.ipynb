# %%
import cv2
from matplotlib import pyplot as plt
from IPython.display import Image

# %%
pt = '../data/train/lp1.png'
Image(pt)

# %%
img = cv2.imread(pt,cv2.IMREAD_GRAYSCALE)
plt.imshow(img,cmap='gray')

# %%
print(img)
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
